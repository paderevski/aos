# %%
install.packages("dplyr")
install.packages("ggplot2")
install.packages("car")
library(dplyr)
library(ggplot2)
# Out:
# The downloaded binary packages are in
# 	/var/folders/f3/xglj46296kg_3m_nmfgtlnsh0000gn/T//RtmplZW1W1/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/f3/xglj46296kg_3m_nmfgtlnsh0000gn/T//RtmplZW1W1/downloaded_packages
# also installing the dependencies ‘pkgbuild’, ‘diffobj’, ‘brio’, ‘desc’, ‘pkgload’, ‘praise’, ‘waldo’, ‘Matrix’, ‘testthat’, ‘numDeriv’, ‘SparseM’, ‘MatrixModels’, ‘minqa’, ‘nloptr’, ‘RcppEigen’, ‘carData’, ‘abind’, ‘pbkrtest’, ‘quantreg’, ‘lme4’
# The downloaded binary packages are in
# 	/var/folders/f3/xglj46296kg_3m_nmfgtlnsh0000gn/T//RtmplZW1W1/downloaded_packages

# %%
set.seed(123) # for reproducibility
Group <- rep(c("A", "B", "C"), each = 10)
Value <- c(rnorm(10, mean = -5, sd = 2), 
           rnorm(10, mean = 6, sd = 2), 
           rnorm(10, mean = 7, sd = 2))
data <- data.frame(Group, Value)

# %%
anova_result <- aov(Value ~ Group, data = data)
summary(anova_result)
# Out:
#             Df Sum Sq Mean Sq F value   Pr(>F)
# Group        2  826.9   413.5   108.7 1.22e-13 ***
# Residuals   27  102.7     3.8
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Check for normality
plot(anova_result, which = 1)

# Check for homogeneity of variances
library(car)
leveneTest(Value ~ Group, data = data)
# Out:
# Warning message in leveneTest.default(y = y, group = group, ...):
# “group coerced to factor.”
#       Df F value      Pr(>F)
# group  2 0.0004977011 0.9995024
#       27           NA        NA
# Plot with title “”

# %%
# Check for normality
plot(anova_result, which = 1)
# Out:
# Plot with title “”

# %%
TukeyHSD(anova_result)
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = Value ~ Group, data = data)
#
# $Group
#           diff       lwr      upr     p adj
# B-A 11.2679926  9.105081 13.43090 0.0000000
# C-A 11.0016310  8.838720 13.16454 0.0000000
# C-B -0.2663617 -2.429273  1.89655 0.9500001

# %%
ggplot(data, aes(x = Group, y = Value)) + 
  geom_boxplot() +
  theme_minimal()
# Out:
# plot without title

# %%
sa = summary(anova_result)

# %%
sa
# Out:
#             Df Sum Sq Mean Sq F value   Pr(>F)
# Group        2  826.9   413.5   108.7 1.22e-13 ***
# Residuals   27  102.7     3.8
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
sa[[1]]
# Out:
#             Df Sum Sq   Mean Sq    F value  Pr(>F)
# Group        2 826.9150 413.457484 108.6633 1.218445e-13
# Residuals   27 102.7334   3.804942       NA           NA

# %%
sa
# Out:
#             Df Sum Sq Mean Sq F value   Pr(>F)
# Group        2  826.9   413.5   108.7 1.22e-13 ***
# Residuals   27  102.7     3.8
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
sa[[2]]
# Out:
# Error in sa[[2]]: subscript out of bounds
# Traceback:

# %%
sa[[1]]
# Out:
#             Df Sum Sq   Mean Sq    F value  Pr(>F)
# Group        2 826.9150 413.457484 108.6633 1.218445e-13
# Residuals   27 102.7334   3.804942       NA           NA

# %%
as.data.frame(sa)
# Out:
# Error in as.data.frame.default(sa): cannot coerce class ‘c("summary.aov", "listof")’ to a data.frame
# Traceback:
#
# 1. as.data.frame(sa)
# 2. as.data.frame.default(sa)
# 3. stop(gettextf("cannot coerce class %s to a data.frame", sQuote(deparse(class(x))[1L])),
#  .     domain = NA)

# %%
df=as.data.frame(sa[[1]])

# %%
df[,1]
# Out:
# [1]  2 27

# %%
df
# Out:
#             Df Sum Sq   Mean Sq    F value  Pr(>F)
# Group        2 826.9150 413.457484 108.6633 1.218445e-13
# Residuals   27 102.7334   3.804942       NA           NA

# %%
df[,2]
# Out:
# [1] 826.9150 102.7334

# %%
library(shiny)

# %%
dataTableOutput(df)
# Out:
# Shiny tags cannot be represented in plain text (need html)

# %%
renderTable(df)
# Out:
# ```r
# structure(function (...)
# {
#     if (length(outputArgs) != 0 && !hasExecuted$get()) {
#         warning("Unused argument: outputArgs. The argument outputArgs is only ",
#             "meant to be used when embedding snippets of Shiny code in an ",
#             "R Markdown code chunk (using runtime: shiny). When running a ",
#             "full Shiny app, please set the output arguments directly in ",
#             "the corresponding output function of your UI code.")
#         hasExecuted$set(TRUE)
#     }
#     if (is.null(formals(renderFunc)))
#         renderFunc()
#     else renderFunc(...)
# }, class = c("shiny.render.function", "function"), outputFunc = function (outputId)
# {
#     div(id = outputId, class = "shiny-html-output")
# }, outputArgs = list(), hasExecuted = <environment>, cacheHint = list(
#     origUserFunc = list(formals = NULL, body = df), renderFunc = list(
#         formals = as.pairlist(alist(shinysession = , name = , ... = )),
#         body = {
# ...

# %%
renderTable({
    df
  })
# Out:
# ```r
# structure(function (...)
# {
#     if (length(outputArgs) != 0 && !hasExecuted$get()) {
#         warning("Unused argument: outputArgs. The argument outputArgs is only ",
#             "meant to be used when embedding snippets of Shiny code in an ",
#             "R Markdown code chunk (using runtime: shiny). When running a ",
#             "full Shiny app, please set the output arguments directly in ",
#             "the corresponding output function of your UI code.")
#         hasExecuted$set(TRUE)
#     }
#     if (is.null(formals(renderFunc)))
#         renderFunc()
#     else renderFunc(...)
# }, class = c("shiny.render.function", "function"), outputFunc = function (outputId)
# {
#     div(id = outputId, class = "shiny-html-output")
# }, outputArgs = list(), hasExecuted = <environment>, cacheHint = list(
#     origUserFunc = list(formals = NULL, body = {
#         df
#     }), renderFunc = list(formals = as.pairlist(alist(shinysession = , name = , ... = )),
# ...

# %%
kr = kruskal.test(Value ~ Group, data = data)

# %%
summary(kr)
# Out:
#           Length Class  Mode
# statistic 1      -none- numeric
# parameter 1      -none- numeric
# p.value   1      -none- numeric
# method    1      -none- character
# data.name 1      -none- character

# %%
kr
# Out:
# 	Kruskal-Wallis rank sum test
#
# data:  Value by Group
# Kruskal-Wallis chi-squared = 19.613, df = 2, p-value = 5.509e-05

# %%
kr[1]
# Out:
# $statistic
# Kruskal-Wallis chi-squared
#                    19.6129

# %%
kr[2]
# Out:
# $parameter
# df
#  2

# %%
kr[3]
# Out:
# $p.value
# [1] 5.5095e-05

# %%
kr[[1]]
# Out:
# Kruskal-Wallis chi-squared
#                    19.6129

# %%
kr[[2]]
# Out:
# df
#  2

# %%
kr[[3]]
# Out:
# [1] 5.5095e-05

# %%
as.data.frame(kr)
# Out:
# Error in as.data.frame.default(kr): cannot coerce class ‘"htest"’ to a data.frame
# Traceback:
#
# 1. as.data.frame(kr)
# 2. as.data.frame.default(kr)
# 3. stop(gettextf("cannot coerce class %s to a data.frame", sQuote(deparse(class(x))[1L])),
#  .     domain = NA)

# %%
kr$statistic
# Out:
# Kruskal-Wallis chi-squared
#                    19.6129

# %%
kr$df
# Out:
# NULL

# %%
kr$method
# Out:
# [1] "Kruskal-Wallis rank sum test"

# %%
kr$parameter
# Out:
# df
#  2

# %%
kr$p.value
# Out:
# [1] 5.5095e-05
